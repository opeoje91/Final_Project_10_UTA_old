# %%
pip install --upgrade mplfinance
# Out:
# Requirement already up-to-date: mplfinance in c:\users\opeoj\anaconda3\envs\pythondata\lib\site-packages (0.12.7a17)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import dependencies
# %matplotlib inline
import pandas as pd
import mplfinance as mpf

# %%
# Import data
file = "AAPL_Pre_Official_DB_7_30.csv"
aapl_df = pd.read_csv(file, parse_dates=['Date'])
#aapl_df.set_index('Unnamed: 0',inplace=True)
#aapl_df.index.name=None
aapl_df.head()
# Out:
#         Date  Year  Month  Season Quarter      Open      High       Low  \
# 0 1980-12-12  1980     12  Winter      Q4  0.128348  0.128906  0.128348
# 1 1980-12-15  1980     12  Winter      Q4  0.122210  0.122210  0.121652
# 2 1980-12-16  1980     12  Winter      Q4  0.113281  0.113281  0.112723
# 3 1980-12-17  1980     12  Winter      Q4  0.115513  0.116071  0.115513
# 4 1980-12-18  1980     12  Winter      Q4  0.118862  0.119420  0.118862
#
#       Close  Adj Close  ...  Open_Change  High_Change  Low_Change  \
# 0  0.128348   0.100751  ...     0.128348     0.128906    0.128348
# 1  0.121652   0.095495  ...    -0.006138    -0.006696   -0.006696
# 2  0.112723   0.088485  ...    -0.008929    -0.008929   -0.008929
# 3  0.115513   0.090676  ...     0.002232     0.002790    0.002790
# 4  0.118862   0.093304  ...     0.003349     0.003349    0.003349
#
#    Close_Change  Volume_Change  Gain_Loss_Open Gain_Loss_High Gain_Loss_Low  \
# ...

# %%
aapl_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10226 entries, 0 to 10225
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              10226 non-null  datetime64[ns]
#  1   Year              10226 non-null  int64
#  2   Month             10226 non-null  int64
#  3   Season            10226 non-null  object
#  4   Quarter           10226 non-null  object
#  5   Open              10226 non-null  float64
#  6   High              10226 non-null  float64
#  7   Low               10226 non-null  float64
#  8   Close             10226 non-null  float64
#  9   Adj Close         10226 non-null  float64
#  10  Volume            10226 non-null  int64
#  11  Open_Change       10226 non-null  float64
#  12  High_Change       10226 non-null  float64
#  13  Low_Change        10226 non-null  float64
#  14  Close_Change      10226 non-null  float64
#  15  Volume_Change     10226 non-null  int64
# ...

# %%
aapl_df.columns
# Out:
# Index(['Date', 'Year', 'Month', 'Season', 'Quarter', 'Open', 'High', 'Low',
#        'Close', 'Adj Close', 'Volume', 'Open_Change', 'High_Change',
#        'Low_Change', 'Close_Change', 'Volume_Change', 'Gain_Loss_Open',
#        'Gain_Loss_High', 'Gain_Loss_Low', 'Gain_Loss_Close',
#        'Gain_Loss_Volume'],
#       dtype='object')

# %%
aapl_df.isnull().sum()
# Out:
# Date                0
# Year                0
# Month               0
# Season              0
# Quarter             0
# Open                0
# High                0
# Low                 0
# Close               0
# Adj Close           0
# Volume              0
# Open_Change         0
# High_Change         0
# Low_Change          0
# Close_Change        0
# Volume_Change       0
# Gain_Loss_Open      0
# Gain_Loss_High      0
# Gain_Loss_Low       0
# Gain_Loss_Close     0
# Gain_Loss_Volume    0
# dtype: int64

# %%
aapl_df = aapl_df.set_index("Date")
#aapl_df = aapl_df.set_index("Season")
aapl_df.head()
# Out:
#             Year  Month  Season Quarter      Open      High       Low  \
# Date
# 1980-12-12  1980     12  Winter      Q4  0.128348  0.128906  0.128348
# 1980-12-15  1980     12  Winter      Q4  0.122210  0.122210  0.121652
# 1980-12-16  1980     12  Winter      Q4  0.113281  0.113281  0.112723
# 1980-12-17  1980     12  Winter      Q4  0.115513  0.116071  0.115513
# 1980-12-18  1980     12  Winter      Q4  0.118862  0.119420  0.118862
#
#                Close  Adj Close     Volume  Open_Change  High_Change  \
# Date
# 1980-12-12  0.128348   0.100751  469033600     0.128348     0.128906
# 1980-12-15  0.121652   0.095495  175884800    -0.006138    -0.006696
# 1980-12-16  0.112723   0.088485  105728000    -0.008929    -0.008929
# 1980-12-17  0.115513   0.090676   86441600     0.002232     0.002790
# 1980-12-18  0.118862   0.093304   73449600     0.003349     0.003349
#
#             Low_Change  Close_Change  Volume_Change Gain_Loss_Open  \
# Date
# ...

# %%
mpf.plot(aapl_df)
# Out:
# C:\Users\opeoj\anaconda3\envs\PythonData\lib\site-packages\mplfinance\_arg_validators.py:45: UserWarning:
#
# ...
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
# ...
#   category=UserWarning)

# %%
mpf.plot(aapl_df, type ="line",volume=True)

# %%
mpf.plot(aapl_df["1996-10"], volume=True)

# %%
mpf.plot(aapl_df["1996-10"], type="candle",volume=True)

# %%
mpf.plot(aapl_df["Winter"], type="candle",volume=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Winter'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-9febdc01e8f3> in <module>
# ...

# %%
mpf.plot(aapl_df["1996-10":"1996-12"], type="candle",volume=True)

# %%
mpf.plot(aapl_df["1996-10":"1996-12"], type="candle",mav=(20),volume=True)

# %%
mpf.plot(aapl_df["1996-10":"1996-12"], type="candle",mav=(20),volume=True, tight_layout=True)

# %%
mpf.plot(aapl_df["1996-10":"1996-12"],figratio=(20,12),
         type="candle",
         title="Amazon Share Price 1996",
         mav=(20),volume=True, 
         tight_layout=True)

# %%
mpf.plot(aapl_df["1996-10":"1996-12"],figratio=(20,12),
         type="candle",
         title="Amazon Share Price 1996",
         mav=(20),volume=True, 
         tight_layout=True,
         style="yahoo"
        )
