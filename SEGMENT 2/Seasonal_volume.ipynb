# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# File to load
AAPL_load = "AAPL_Pre_Official_DB_7_31.csv"

#Read data
AAPL_df = pd.read_csv(AAPL_load)
AAPL_df.head()
# Out:
#        Date Day_Month  Year  Month  Season Quarter      Open      High  \
# 0  12/12/80     12/12  1980     12  Winter      Q4  0.128348  0.128906
# 1  12/15/80     12/15  1980     12  Winter      Q4  0.122210  0.122210
# 2  12/16/80     12/16  1980     12  Winter      Q4  0.113281  0.113281
# 3  12/17/80     12/17  1980     12  Winter      Q4  0.115513  0.116071
# 4  12/18/80     12/18  1980     12  Winter      Q4  0.118862  0.119420
#
#         Low     Close  ...  Open_Change  High_Change  Low_Change  \
# 0  0.128348  0.128348  ...     0.128348     0.128906    0.128348
# 1  0.121652  0.121652  ...    -0.006138    -0.006696   -0.006696
# 2  0.112723  0.112723  ...    -0.008929    -0.008929   -0.008929
# 3  0.115513  0.115513  ...     0.002232     0.002790    0.002790
# 4  0.118862  0.118862  ...     0.003349     0.003349    0.003349
#
#    Close_Change  Volume_Change  Gain_Loss_Open  Gain_Loss_High Gain_Loss_Low  \
# ...

# %%
AAPL_years = AAPL_df.Year.unique()
AAPL_years
# Out:
# array([1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990,
#        1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001,
#        2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012,
#        2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021], dtype=int64)

# %%
AAPL_spring_df = AAPL_df[AAPL_df["Season"] == "Spring"]
AAPL_spring_df.head()
# Out:
#       Date Day_Month  Year  Month  Season Quarter      Open      High  \
# 54  3/2/81     03/02  1981      3  Spring      Q1  0.123326  0.123884
# 55  3/3/81     03/03  1981      3  Spring      Q1  0.117746  0.117746
# 56  3/4/81     03/04  1981      3  Spring      Q1  0.118304  0.118862
# 57  3/6/81     03/06  1981      3  Spring      Q1  0.140625  0.141741
# 58  3/8/81     03/08  1981      3  Spring      Q1  0.111607  0.111607
#
#          Low     Close  ...  Open_Change  High_Change  Low_Change  \
# 54  0.123326  0.123326  ...     0.005022     0.004464    0.005022
# 55  0.117188  0.117188  ...    -0.005580    -0.006138   -0.006138
# 56  0.118304  0.118304  ...     0.000558     0.001116    0.001116
# 57  0.140625  0.140625  ...     0.022321     0.022879    0.022321
# 58  0.110491  0.110491  ...    -0.029018    -0.030134   -0.030134
#
#     Close_Change  Volume_Change  Gain_Loss_Open  Gain_Loss_High Gain_Loss_Low  \
# ...

# %%
AAPL_summer_df = AAPL_df[AAPL_df["Season"] == "Summer"]
AAPL_summer_df.head()
# Out:
#        Date Day_Month  Year  Month  Season Quarter      Open      High  \
# 116  6/1/81     06/01  1981      6  Summer      Q2  0.144531  0.144531
# 117  6/2/81     06/02  1981      6  Summer      Q2  0.128348  0.128906
# 118  6/3/81     06/03  1981      6  Summer      Q2  0.115513  0.115513
# 119  6/4/81     06/04  1981      6  Summer      Q2  0.116629  0.116629
# 120  6/5/81     06/05  1981      6  Summer      Q2  0.122768  0.122768
#
#           Low     Close  ...  Open_Change  High_Change  Low_Change  \
# 116  0.143973  0.143973  ...    -0.003348    -0.003907   -0.003906
# 117  0.128348  0.128348  ...    -0.016183    -0.015625   -0.015625
# 118  0.114397  0.114397  ...    -0.012835    -0.013393   -0.013951
# 119  0.116071  0.116071  ...     0.001116     0.001116    0.001674
# 120  0.122210  0.122210  ...     0.006139     0.006139    0.006139
#
#      Close_Change  Volume_Change  Gain_Loss_Open  Gain_Loss_High  \
# 116     -0.003906      -14224000            Loss            Loss
# ...

# %%
AAPL_fall_df = AAPL_df[AAPL_df["Season"] == "Fall"]
AAPL_fall_df.head()
# Out:
#        Date Day_Month  Year  Month Season Quarter      Open      High  \
# 180  9/1/81     09/01  1981      9   Fall      Q3  0.142299  0.142857
# 181  9/2/81     09/02  1981      9   Fall      Q3  0.122768  0.122768
# 182  9/3/81     09/03  1981      9   Fall      Q3  0.106027  0.106027
# 183  9/4/81     09/04  1981      9   Fall      Q3  0.122768  0.123326
# 184  9/6/81     09/06  1981      9   Fall      Q3  0.138951  0.139509
#
#           Low     Close  ...  Open_Change  High_Change  Low_Change  \
# 180  0.142299  0.142299  ...     0.052455     0.052455    0.052455
# 181  0.121652  0.121652  ...    -0.019531    -0.020089   -0.020647
# 182  0.105469  0.105469  ...    -0.016741    -0.016741   -0.016183
# 183  0.122768  0.122768  ...     0.016741     0.017299    0.017299
# 184  0.138951  0.138951  ...     0.016183     0.016183    0.016183
#
#      Close_Change  Volume_Change  Gain_Loss_Open  Gain_Loss_High  \
# 180      0.052455      -19443200            Gain            Gain
# ...

# %%
AAPL_winter_df = AAPL_df[AAPL_df["Season"] == "Winter"]
AAPL_winter_df.head()
# Out:
#        Date Day_Month  Year  Month  Season Quarter      Open      High  \
# 0  12/12/80     12/12  1980     12  Winter      Q4  0.128348  0.128906
# 1  12/15/80     12/15  1980     12  Winter      Q4  0.122210  0.122210
# 2  12/16/80     12/16  1980     12  Winter      Q4  0.113281  0.113281
# 3  12/17/80     12/17  1980     12  Winter      Q4  0.115513  0.116071
# 4  12/18/80     12/18  1980     12  Winter      Q4  0.118862  0.119420
#
#         Low     Close  ...  Open_Change  High_Change  Low_Change  \
# 0  0.128348  0.128348  ...     0.128348     0.128906    0.128348
# 1  0.121652  0.121652  ...    -0.006138    -0.006696   -0.006696
# 2  0.112723  0.112723  ...    -0.008929    -0.008929   -0.008929
# 3  0.115513  0.115513  ...     0.002232     0.002790    0.002790
# 4  0.118862  0.118862  ...     0.003349     0.003349    0.003349
#
#    Close_Change  Volume_Change  Gain_Loss_Open  Gain_Loss_High Gain_Loss_Low  \
# ...

# %%
AAPL_spring_avg = AAPL_spring_df.groupby(["Year"]).mean()["Volume"]
AAPL_spring_avg.head()
# Out:
# Year
# 1981    3.339479e+07
# 1982    7.507662e+07
# 1983    1.338075e+08
# 1984    1.724536e+08
# 1985    1.699792e+08
# Name: Volume, dtype: float64
